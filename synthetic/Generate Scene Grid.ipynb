# %% [markdown]
# # Generate a grid of two-galaxy scenes
#
# This notebook produces a folder structure and collection of FITS files in the working directory containing scene simulation outputs. The scene shows two elliptical galaxies with different SEDs from the Bruzal-Charlot Atlas (`bc95`) positioned on the horizontal axis through the center of the image. The "A" galaxy major axis is aligned with the x axis and the "B" galaxy major axis is rotated 90 degrees.
#
# We will vary these parameters:
#
#   - Galaxy B magnitude (Galaxy A mag + $\Delta m$) -- $\Delta m \in \{0, 1, 2, 3\}$
#   - difference in redshift between two galaxies -- $\Delta z \in \{0, 1, 2\}$
#   - center-to-center separation along x axis -- $\Delta x \in \{0.5'', 0.75'', 1.0'', 1.25''\}$
#
# We are holding these parameters constant to make the high-dimensional parameter space a little more manageable at first:
#
#   - effective radius (25 px or 5 arcsec for both)
#   - Sérsic index (n=4 for both)
#   - ellipticity (0.5 for both)
#   - Galaxy A magnitude (18 ABmag)
#
# We're using these bandpasses from SDSS: *u*, *g*, *r*, *i*, *z*.

# %%
from __future__ import print_function, division
import glob
from astropy.io import fits
import astropy.modeling.models as models
import numpy as np
from scipy import stats
import astropy.stats
import astropy.table
from astropy import wcs
from astropy import convolution
# import lupton_rgb
import img_scale

# %%
# %matplotlib inline
import matplotlib
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
plt.style.use('ggplot')
matplotlib.rcParams['image.interpolation'] = 'nearest'

# %%
import os
from os.path import exists, isdir, basename, split, join

_pysynphot_ref_file_roots = (
    '/Users/hcferguson/data/cdbs',
    '/Users/jlong/cdbs',
    '/grp/hst/cdbs'
)
if not os.environ.get('PYSYN_CDBS', False):
    for location in _pysynphot_ref_file_roots:
        if isdir(location):
            os.environ['PYSYN_CDBS'] = location

assert os.environ.get('PYSYN_CDBS', False)
import pysynphot

# %%
GALAXY_A_PATH = os.environ['PYSYN_CDBS'] + '/grid/bc95/templates/bc95_c_10E9.fits'
GALAXY_B_PATH = os.environ['PYSYN_CDBS'] + '/grid/bc95/templates/bc95_c_10E7.fits'
STAR_PATH = os.environ['PYSYN_CDBS'] + '/grid/pickles/dat_uvk/pickles_uk_9.fits'
SOLAR_PATH = os.environ['PYSYN_CDBS']  + '/calspec/sun_reference_001.fits'

LSST_FWHM_ARCSEC = 0.7
LSST_PIXEL_SCALE = 0.2
SDSS_BANDS = ('u', 'g', 'r', 'i', 'z')

# %%
def ensure_dir(dirpath):
    try:
        os.makedirs(dirpath)
    except OSError:
        if not isdir(dirpath):
            raise
    return dirpath

# %%
OUTPUT_PATH = './outputs/TwoGalaxies-A'
ensure_dir(OUTPUT_PATH)
# Out:
# './outputs/TwoGalaxies-A'

# %%
from quickscene import Scene, ChromaticGaussianPSF

# %%
chromatic_psf = ChromaticGaussianPSF(
    fwhm_arcsec=0.7,
    reference_wavelength=pysynphot.ObsBandpass('sdss,i').avgwave()
)
hdulist = chromatic_psf.fits_for_bands('ugriz', LSST_PIXEL_SCALE)
hdulist.writeto(join(OUTPUT_PATH, 'chromatic_gaus_0.7_arcsec_sdss_i.fits'), clobber=True)
hdulist.info()
# Out:
# Filename: (No file associated with this HDUList)
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       7   ()
# 1    U           ImageHDU        10   (25, 25)     float64
# 2    G           ImageHDU        10   (25, 25)     float64
# 3    R           ImageHDU        10   (25, 25)     float64
# 4    I           ImageHDU        10   (25, 25)     float64
# 5    Z           ImageHDU        10   (25, 25)     float64

# %% [markdown]
# # Do one scene

# %%
scene = Scene(
    chromatic_psf=chromatic_psf,
    # alternatively, constant angular size with wavelength: kernel_fwhm_arcsec=0.7,
    width_px=256,
    height_px=256,
)
scene.add_sersic_galaxy(
    spectrum=GALAXY_A_PATH,
    redshift=0.0,
    abmag=20.,
    r_eff_arcsec=25 * 0.2,
    sersic_index=4.,
    x_arcsec=0,
    y_arcsec=0,
    ellipticity=0.5,
    theta=0.6,
)
scene.add_sersic_galaxy(
    spectrum=GALAXY_B_PATH,
    redshift=0.0,
    abmag=22.,
    r_eff_arcsec=10 * 0.2,
    sersic_index=1.,
    x_arcsec=6.0,
    y_arcsec=6.0,
    ellipticity=0.8
)
scene.add_star(
    spectrum=STAR_PATH,
    abmag=20.,
    x_arcsec=-5.6,
    y_arcsec=-5.6,
)

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))
for idx, band in enumerate(scene.bands):
    scene.display(band=band, ax=axes.flatten()[idx], norm=LogNorm())

scene.display_rgb(ax=axes.flatten()[-1], norm=LogNorm())
plt.tight_layout()
# Out:
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 817.481949986
# g model counts = 4541.65280104
# r model counts = 9997.87807712
# i model counts = 14726.1583305
# z model counts = 21098.9090474
# u model counts = 860.577288257
# g model counts = 1558.04492354
# r model counts = 1584.55689035
# i model counts = 1647.51630374
# z model counts = 1767.21322648
# u model counts = 4906.88766985
# g model counts = 12374.1792954
# r model counts = 9997.87807712
# i model counts = 8443.96234899
# z model counts = 7255.78911466
# u sky level = 840076.698325
# g sky level = 2691873.12752
# r sky level = 4175401.12768
# i sky level = 4605562.30439
# z sky level = 4695741.1943

# %%
scene.truth_canvas.shape
# Out:
# (5, 512, 512)

# %%
scene.canvas.shape
# Out:
# (5, 256, 256)

# %% [markdown]
# # Build grid

# %%
BASE_MAGNITUDE = 15
BASE_REDSHIFT = 0.0

def build_scene(delta_mag, delta_z, separation, theta):
    galaxy_1_mag = BASE_MAGNITUDE
    galaxy_1_z = BASE_REDSHIFT
    galaxy_1_coords = -separation / 2., 0
    galaxy_1_theta = 0.0
    print("Galaxy 1: magnitude = {}, redshift = {}, position = {}".format(
        galaxy_1_mag,
        galaxy_1_z,
        galaxy_1_coords,
    ))
    galaxy_2_mag = BASE_MAGNITUDE + delta_mag
    galaxy_2_z = BASE_REDSHIFT + delta_z
    galaxy_2_coords = +separation / 2., 0
    galaxy_2_theta = theta
    print("Galaxy 2: magnitude = {}, redshift = {}, position = {}".format(
        galaxy_2_mag,
        galaxy_2_z,
        galaxy_2_coords,
#         galaxy_2_theta
    ))
    scene = Scene(
        chromatic_psf=chromatic_psf,
        width_px=64,
        height_px=64,
    )
    scene.add_sersic_galaxy(
        spectrum=GALAXY_A_PATH,
        redshift=BASE_REDSHIFT,
        abmag=galaxy_1_mag,
        r_eff_arcsec=25 * 0.2,
        sersic_index=4.,
        x_arcsec=galaxy_1_coords[0],
        y_arcsec=galaxy_1_coords[1],
        ellipticity=0.5,
        theta=galaxy_1_theta,
    )
    scene.add_sersic_galaxy(
        spectrum=GALAXY_B_PATH,
        redshift=BASE_REDSHIFT + delta_z,
        abmag=galaxy_2_mag,
        r_eff_arcsec=25 * 0.2,
        sersic_index=4.,
        x_arcsec=galaxy_2_coords[0],
        y_arcsec=galaxy_2_coords[1],
        ellipticity=0.5,
        theta=galaxy_2_theta,
    )
    return scene
    
scenes = []
    
for delta_magnitude in (0, 1, 2, 3): # 6 mag is ~100 fold, overkill
    for delta_redshift in (0, 1, 2):
        for separation in (0.5, 0.75, 1., 1.25):
            theta = np.pi / 2
            scene = build_scene(delta_magnitude, delta_redshift, separation, theta)
            scenes.append(scene)
#             filepath = join(OUTPUT_PATH, 'delta_mag_{delta_magnitude}/delta_z_{delta_redshift:1.1f}/sep_{separation:1.3f}_arcsec.fits').format(
# #                 magA=BASE_MAGNITUDE,
# #                 zA=BASE_REDSHIFT,
#                 delta_magnitude=delta_magnitude,
#                 delta_redshift=delta_redshift,
#                 separation=separation
#             )
            blend_id = 'TwoGalaxies-A--dm-{delta_magnitude}-dz-{delta_redshift:1.1f}-sep-{separation:1.3f}'.format(
                delta_magnitude=delta_magnitude,
                delta_redshift=delta_redshift,
                separation=separation
            )
            filepath = join(OUTPUT_PATH, blend_id + '.fits')
            blend_name = 'TwoGalaxies-A (delta mag={delta_magnitude}, delta z={delta_redshift:1.1f}, separation={separation:1.3f} arcsec)'.format(
                delta_magnitude=delta_magnitude,
                delta_redshift=delta_redshift,
                separation=separation
            )
#             dirs, filename = split(filepath)
#             ensure_dir(dirs)
#             print(filename)
            hdu_list = scene.to_hdu_list(filepath)
            
            hdr = hdu_list['PRIMARY'].header
            hdr.extend((
                    ('NAME', blend_name, 'Human-friendly unique name for this blend'),
                    ('BLEND-ID', blend_id, 'Unique identifier within the deblending datasets'),
                    ('GALAMAG', BASE_MAGNITUDE, 'ABmag of Galaxy A'),
                    ('GALAZ', BASE_REDSHIFT, 'redshift z of Galaxy A'),
                    ('DELTAMAG', delta_magnitude, 'ABmag(Galaxy B) - ABmag(Galaxy A)'),
                    ('DELTAZ', delta_redshift, 'z(Galaxy B) - z(Galaxy A)'),
                    ('SEPARATE', separation, 'center-to-center dist. between sources, arcsec'),
            ))
            hdu_list.writeto(filepath, clobber=True)
            print("saved {}".format(filepath))
            
            fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))
            for idx, band in enumerate(scene.bands):
                scene.display(band=band, ax=axes.flatten()[idx], norm=LogNorm())

            scene.display_rgb(ax=axes.flatten()[-1], norm=LogNorm())
            plt.tight_layout()
            plt.savefig(filepath.replace('.fits', '.png'))
            plt.close()
# Out:
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.25, 0)
# Galaxy 2: magnitude = 15, redshift = 0.0, position = (0.25, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 542987.560519
# g model counts = 983059.887538
# r model counts = 999787.807712
# i model counts = 1039512.512
# z model counts = 1115036.16451
# u sky level = 676828.989981
# g sky level = 1604312.6208
# r sky level = 2259189.41634
# i sky level = 2798424.88676
# z sky level = 3516528.27443
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-0.0-sep-0.500.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.375, 0)
# Galaxy 2: magnitude = 15, redshift = 0.0, position = (0.375, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 542987.560519
# g model counts = 983059.887538
# r model counts = 999787.807712
# i model counts = 1039512.512
# z model counts = 1115036.16451
# u sky level = 676828.989981
# g sky level = 1604312.6208
# r sky level = 2259189.41634
# i sky level = 2798424.88676
# z sky level = 3516528.27443
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-0.0-sep-0.750.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.5, 0)
# Galaxy 2: magnitude = 15, redshift = 0.0, position = (0.5, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 542987.560519
# g model counts = 983059.887538
# r model counts = 999787.807712
# i model counts = 1039512.512
# z model counts = 1115036.16451
# u sky level = 676828.989981
# g sky level = 1604312.6208
# r sky level = 2259189.41634
# i sky level = 2798424.88676
# z sky level = 3516528.27443
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-0.0-sep-1.000.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.625, 0)
# Galaxy 2: magnitude = 15, redshift = 0.0, position = (0.625, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 542987.560519
# g model counts = 983059.887538
# r model counts = 999787.807712
# i model counts = 1039512.512
# z model counts = 1115036.16451
# u sky level = 676828.989981
# g sky level = 1604312.6208
# r sky level = 2259189.41634
# i sky level = 2798424.88676
# z sky level = 3516528.27443
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-0.0-sep-1.250.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.25, 0)
# Galaxy 2: magnitude = 15, redshift = 1.0, position = (0.25, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 929450.959046
# g model counts = 832666.525259
# r model counts = 999787.807712
# i model counts = 1404244.69611
# z model counts = 2127548.35556
# u sky level = 1063292.38851
# g sky level = 1453919.25852
# r sky level = 2259189.41634
# i sky level = 3163157.07087
# z sky level = 4529040.46548
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-1.0-sep-0.500.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.375, 0)
# Galaxy 2: magnitude = 15, redshift = 1.0, position = (0.375, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 929450.959046
# g model counts = 832666.525259
# r model counts = 999787.807712
# i model counts = 1404244.69611
# z model counts = 2127548.35556
# u sky level = 1063292.38851
# g sky level = 1453919.25852
# r sky level = 2259189.41634
# i sky level = 3163157.07087
# z sky level = 4529040.46548
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-1.0-sep-0.750.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.5, 0)
# Galaxy 2: magnitude = 15, redshift = 1.0, position = (0.5, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 929450.959046
# g model counts = 832666.525259
# r model counts = 999787.807712
# i model counts = 1404244.69611
# z model counts = 2127548.35556
# u sky level = 1063292.38851
# g sky level = 1453919.25852
# r sky level = 2259189.41634
# i sky level = 3163157.07087
# z sky level = 4529040.46548
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-1.0-sep-1.000.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.625, 0)
# Galaxy 2: magnitude = 15, redshift = 1.0, position = (0.625, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 929450.959046
# g model counts = 832666.525259
# r model counts = 999787.807712
# i model counts = 1404244.69611
# z model counts = 2127548.35556
# u sky level = 1063292.38851
# g sky level = 1453919.25852
# r sky level = 2259189.41634
# i sky level = 3163157.07087
# z sky level = 4529040.46548
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-1.0-sep-1.250.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.25, 0)
# Galaxy 2: magnitude = 15, redshift = 2.0, position = (0.25, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 596294.806902
# g model counts = 1233330.44203
# r model counts = 999787.807712
# i model counts = 1056914.12635
# z model counts = 1194456.79568
# u sky level = 730136.236364
# g sky level = 1854583.17529
# r sky level = 2259189.41634
# i sky level = 2815826.50111
# z sky level = 3595948.9056
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-2.0-sep-0.500.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.375, 0)
# Galaxy 2: magnitude = 15, redshift = 2.0, position = (0.375, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 596294.806902
# g model counts = 1233330.44203
# r model counts = 999787.807712
# i model counts = 1056914.12635
# z model counts = 1194456.79568
# u sky level = 730136.236364
# g sky level = 1854583.17529
# r sky level = 2259189.41634
# i sky level = 2815826.50111
# z sky level = 3595948.9056
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-2.0-sep-0.750.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.5, 0)
# Galaxy 2: magnitude = 15, redshift = 2.0, position = (0.5, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 596294.806902
# g model counts = 1233330.44203
# r model counts = 999787.807712
# i model counts = 1056914.12635
# z model counts = 1194456.79568
# u sky level = 730136.236364
# g sky level = 1854583.17529
# r sky level = 2259189.41634
# i sky level = 2815826.50111
# z sky level = 3595948.9056
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-2.0-sep-1.000.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.625, 0)
# Galaxy 2: magnitude = 15, redshift = 2.0, position = (0.625, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 596294.806902
# g model counts = 1233330.44203
# r model counts = 999787.807712
# i model counts = 1056914.12635
# z model counts = 1194456.79568
# u sky level = 730136.236364
# g sky level = 1854583.17529
# r sky level = 2259189.41634
# i sky level = 2815826.50111
# z sky level = 3595948.9056
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-0-dz-2.0-sep-1.250.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.25, 0)
# Galaxy 2: magnitude = 16, redshift = 0.0, position = (0.25, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 216167.241364
# g model counts = 391363.190313
# r model counts = 398022.695282
# i model counts = 413837.384906
# z model counts = 443903.892518
# u sky level = 350008.670826
# g sky level = 1012615.92357
# r sky level = 1657424.30391
# i sky level = 2172749.75967
# z sky level = 2845396.00244
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-1-dz-0.0-sep-0.500.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.375, 0)
# Galaxy 2: magnitude = 16, redshift = 0.0, position = (0.375, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 216167.241364
# g model counts = 391363.190313
# r model counts = 398022.695282
# i model counts = 413837.384906
# z model counts = 443903.892518
# u sky level = 350008.670826
# g sky level = 1012615.92357
# r sky level = 1657424.30391
# i sky level = 2172749.75967
# z sky level = 2845396.00244
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-1-dz-0.0-sep-0.750.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.5, 0)
# Galaxy 2: magnitude = 16, redshift = 0.0, position = (0.5, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 216167.241364
# g model counts = 391363.190313
# r model counts = 398022.695282
# i model counts = 413837.384906
# z model counts = 443903.892518
# u sky level = 350008.670826
# g sky level = 1012615.92357
# r sky level = 1657424.30391
# i sky level = 2172749.75967
# z sky level = 2845396.00244
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-1-dz-0.0-sep-1.000.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.625, 0)
# Galaxy 2: magnitude = 16, redshift = 0.0, position = (0.625, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 216167.241364
# g model counts = 391363.190313
# r model counts = 398022.695282
# i model counts = 413837.384906
# z model counts = 443903.892518
# u sky level = 350008.670826
# g sky level = 1012615.92357
# r sky level = 1657424.30391
# i sky level = 2172749.75967
# z sky level = 2845396.00244
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-1-dz-0.0-sep-1.250.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.25, 0)
# Galaxy 2: magnitude = 16, redshift = 1.0, position = (0.25, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# ...
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 58644.3908944
# g model counts = 52537.7059615
# r model counts = 63082.3460198
# i model counts = 88601.8504456
# z model counts = 134239.226067
# u sky level = 192485.820357
# g sky level = 673790.439222
# r sky level = 1322483.95465
# i sky level = 1847514.22521
# z sky level = 2535731.33599
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-3-dz-1.0-sep-1.000.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.625, 0)
# Galaxy 2: magnitude = 18, redshift = 1.0, position = (0.625, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 58644.3908944
# g model counts = 52537.7059615
# r model counts = 63082.3460198
# i model counts = 88601.8504456
# z model counts = 134239.226067
# u sky level = 192485.820357
# g sky level = 673790.439222
# r sky level = 1322483.95465
# i sky level = 1847514.22521
# z sky level = 2535731.33599
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-3-dz-1.0-sep-1.250.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.25, 0)
# Galaxy 2: magnitude = 18, redshift = 2.0, position = (0.25, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 37623.658789
# g model counts = 77817.8900568
# r model counts = 63082.3460198
# i model counts = 66686.7730503
# z model counts = 75365.12879
# u sky level = 171465.088251
# g sky level = 699070.623317
# r sky level = 1322483.95465
# i sky level = 1825599.14782
# z sky level = 2476857.23871
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-3-dz-2.0-sep-0.500.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.375, 0)
# Galaxy 2: magnitude = 18, redshift = 2.0, position = (0.375, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 37623.658789
# g model counts = 77817.8900568
# r model counts = 63082.3460198
# i model counts = 66686.7730503
# z model counts = 75365.12879
# u sky level = 171465.088251
# g sky level = 699070.623317
# r sky level = 1322483.95465
# i sky level = 1825599.14782
# z sky level = 2476857.23871
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-3-dz-2.0-sep-0.750.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.5, 0)
# Galaxy 2: magnitude = 18, redshift = 2.0, position = (0.5, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 37623.658789
# g model counts = 77817.8900568
# r model counts = 63082.3460198
# i model counts = 66686.7730503
# z model counts = 75365.12879
# u sky level = 171465.088251
# g sky level = 699070.623317
# r sky level = 1322483.95465
# i sky level = 1825599.14782
# z sky level = 2476857.23871
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-3-dz-2.0-sep-1.000.fits
# Galaxy 1: magnitude = 15, redshift = 0.0, position = (-0.625, 0)
# Galaxy 2: magnitude = 18, redshift = 2.0, position = (0.625, 0)
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_u_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_g_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_r_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_i_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# (/grp/hst/cdbs/comp/nonhst/sdss_z_005_syn.fits) does not have a defined binset in the wavecat table. The waveset of the spectrum will be used instead.
# u model counts = 81748.1949986
# g model counts = 454165.280104
# r model counts = 999787.807712
# i model counts = 1472615.83305
# z model counts = 2109890.90474
# u model counts = 37623.658789
# g model counts = 77817.8900568
# r model counts = 63082.3460198
# i model counts = 66686.7730503
# z model counts = 75365.12879
# u sky level = 171465.088251
# g sky level = 699070.623317
# r sky level = 1322483.95465
# i sky level = 1825599.14782
# z sky level = 2476857.23871
# saved ./outputs/TwoGalaxies-A/TwoGalaxies-A--dm-3-dz-2.0-sep-1.250.fits

# %%
plt.imsave('./outputs/TwoGalaxies-A/preview.png', scene.canvas[0], cmap='magma')

# %%
pwd
# Out:
# u'/astro/ferguson1/jlong/deblend/synthetic'

# %%
ls
# Out:
# Generate Scene Grid.ipynb                         img_scale.pyc  quickscene.pyc
# Generate an input scene for meas_deblender.ipynb  outputs/       utils.py
# __pycache__/                                      preview.png
# img_scale.py                                      quickscene.py

# %%
ls outputs/TwoGalaxies-A/
# Out:
# TwoGalaxies-A--dm-0-dz-0.0-sep-0.500.fits
# TwoGalaxies-A--dm-0-dz-0.0-sep-0.500.png
# TwoGalaxies-A--dm-0-dz-0.0-sep-0.750.fits
# TwoGalaxies-A--dm-0-dz-0.0-sep-0.750.png
# TwoGalaxies-A--dm-0-dz-0.0-sep-1.000.fits
# TwoGalaxies-A--dm-0-dz-0.0-sep-1.000.png
